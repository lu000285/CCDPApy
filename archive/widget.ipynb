# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 300)

# %%
file = '/Users/galileo/development/Reserch/UMN_Research/CCDPA_git/CCDPApy/input_files/perfusion_temp.xlsx'
df = pd.read_excel(file)

# %%
df.head()
# Out:
#         Description          Unnamed: 1 Unnamed: 2 Experimental Data  \
# 0         Cell Line     Experimental ID       Name          Sample #
# 1  Sample Perfusion  Sample Perfusion 1  perfusion                 0
# 2               NaN                 NaN        NaN                 1
# 3               NaN                 NaN        NaN                 2
# 4               NaN                 NaN        NaN                 3
#
#   Unnamed: 4 Unnamed: 5           Unnamed: 6          Unnamed: 7  \
# 0       Date       Time  Initial Volume (mL)  Sample Volume (mL)
# 1        NaN          0                  NaN                 NaN
# 2        NaN         10                  NaN                 NaN
# 3        NaN         20                  NaN                 NaN
# 4        NaN         25                  NaN                 NaN
#
#                    Unnamed: 8             Unnamed: 9      Unnamed: 10  \
# 0  Volume After Sampling (mL)  Feed Media Added (mL)  Base Added (mL)
# ...

# %%
columns = ['Experimental Data', 
           'Product Concentration', 
           'Concentration Before Feeding',
           'Concentration After Feeding',
           'Feed Concentration']
indices = [i for i, s in enumerate(df.columns) if s in columns]
indices
# Out:
# [3, 22, 23, 27]

# %%
df.iloc[:, :indices[0]].head()
# Out:
#         Description          Unnamed: 1 Unnamed: 2
# 0         Cell Line     Experimental ID       Name
# 1  Sample Perfusion  Sample Perfusion 1  perfusion
# 2               NaN                 NaN        NaN
# 3               NaN                 NaN        NaN
# 4               NaN                 NaN        NaN

# %%
df.iloc[:, indices[0]:indices[1]].head()
# Out:
#   Experimental Data Unnamed: 4 Unnamed: 5           Unnamed: 6  \
# 0          Sample #       Date       Time  Initial Volume (mL)
# 1                 0        NaN          0                  NaN
# 2                 1        NaN         10                  NaN
# 3                 2        NaN         20                  NaN
# 4                 3        NaN         25                  NaN
#
#            Unnamed: 7                  Unnamed: 8             Unnamed: 9  \
# 0  Sample Volume (mL)  Volume After Sampling (mL)  Feed Media Added (mL)
# 1                 NaN                         NaN                      0
# 2                 NaN                         NaN                      0
# 3                 NaN                         NaN                      0
# 4                 NaN                         NaN                      0
#
#        Unnamed: 10                               Unnamed: 11  \
# 0  Base Added (mL)  Viable Cell Concentration (106 cells/ml)
# ...
